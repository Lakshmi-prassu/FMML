# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshmi-prassu/FMML/blob/main/Copy_of_FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 14:13:20--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   127MB/s    in 0.5s
#
# 2024-03-31 14:13:21 (127 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 3544 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 23205   1004.1227v1  This paper present a novel off-line signature ...    cs
# 22328  1602.02964v4  We propose a nonparametric statistical test fo...  stat
# 10802   1405.2377v1  Much recent research has been conducted in the...  stat
# 17933  cs/9609101v1  We propose some domain-independent techniques ...    cs
# 7743   1803.01043v1  An image pattern can be represented by a proba...  stat
# ...             ...                                                ...   ...
# 7388   1712.03847v1  Elastic weight consolidation (EWC, Kirkpatrick...  stat
# 22986  1712.06206v1  We consider the problem of clustering with the...  stat
# 17461  1711.04731v1  Zero-shot translation is the task of translati...    cs
# 22316  1601.01190v3  This paper is about index policies for minimiz...  stat
# 20660  1609.05566v1  In many machine learning applications, labeled...    cs
#
#                                                    title  year  \
# 23205  Signature Recognition using Multi Scale Fourie...  2010
# 22328                   A Kernel Test of Goodness of Fit  2016
# 10802  A Hybrid Monte Carlo Architecture for Paramete...  2014
# 17933  Accelerating Partial-Order Planners: Some Tech...  1996
# 7743   Building a Telescope to Look Into High-Dimensi...  2018
# ...                                                  ...   ...
# 7388   On Quadratic Penalties in Elastic Weight Conso...  2017
# 22986  Path-Based Spectral Clustering: Guarantees, Ro...  2017
# 17461  Zero-Shot Style Transfer in Text Using Recurre...  2017
# 22316  On Bayesian index policies for sequential reso...  2016
# 20660  Label-Free Supervision of Neural Networks with...  2016
#
#                                                 keywords
# 23205  [signature, recognition, descriptor, transform...
# 22328  [nonparametric, statistical, determines, gener...
# 10802  [conducted, particularly, optimization, parame...
# 17933  [independent, techniques, practicality, techni...
# 7743   [represented, probability, distribution, conce...
# ...                                                  ...
# 7388   [consolidation, kirkpatrick, algorithm, safegu...
# 22986  [clustering, informative, elongated, irregular...
# 17461  [translation, translating, paraphrases, stylis...
# 22316  [minimizing, stochastic, contribution, algorit...
# 20660  [applications, obtaining, expensive, introduce...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 23205    [signature, recognition, descriptor, transform...
# 22328    [nonparametric, statistical, determines, gener...
# 10802    [conducted, particularly, optimization, parame...
# 17933    [independent, techniques, practicality, techni...
# 7743     [represented, probability, distribution, conce...
#                                ...
# 11284    [nonnegative, factorization, introduced, appro...
# 31693    [independently, according, distribution, stoch...
# 34524    [financial, institutions, transactions, affili...
# 92       [recurrent, modelling, automatic, recognition,...
# 14059    [artificial, inadequate, biological, inadequac...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8845 words.
# Out of those 4525 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cdcac310-9f98-41ff-9336-972908eb2206" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cdcac310-9f98-41ff-9336-972908eb2206")) {                    Plotly.newPlot(                        "cdcac310-9f98-41ff-9336-972908eb2206",                        [{"x":["transform","discussed","performance","constructing","recognition","signature","experiments","verification","descriptor","determines","reproducing","convergence","generated","bootstrap","constructed","evaluating","distribution","quantifying","statistical","estimation","criticism","procedure","gradients","empirical","nonparametric","functions","complexity","divergence","approximate","quantiles","statistic","parameter","uncertainties","particularly","improvement","methodologies","demonstrate","architecture","maximizing","regression","intervals","algorithm","competitive","discovery","adjustments","conducted","parameters","optimization","confidence","modifications","initially","adjustment","appendices","commitment","practicality","prioritization","technique","otherwise","propagates","conditions","strategies","nontrivial","difficult","techniques","constants","operators","definitions","refinement","refinements","selection","magnitude","independent","unmodified","heuristic","polynomial","accelerating","effective","improvements","instances","crucially","improving","dimensional","countless","telescope","subspaces","potential","structure","penalizing","synthesizing","macroscopic","realistic","visualize","facilitate","computational","stability","generator","represent","challenge","probability","identifying","efficiently","concentrated","efficient","different","differences","diffusion","characterizing","corresponding","influences","appearances","densities","enumerating","represented","exploration","dimensions","measuring","statistics","metastable","attraction","translation","heuristically","summarizing","achieving","architectures","convolutional","treatment","predicting","representation","specifically","significant","systematic","information","measurements","laplacian","breathing","providing","modelling","computationally","demonstrated","requiring","qualitatively","approximation","bandlimited","acquisition","introduce","undersampled","performed","framework","reconstructions","reconstruction","application","mathematical","philosophy","properties","automated","furthermore","considered","researched","reasoning","argumentation","prediction","distillation","community","predictive","parametric","empirically","inference","processes","knowledge","alternatives","distilled","stationary","evaluated","optimally","available","designing","asymptotically","algorithms","allocation","maximizes","minimizing","interpolation","introduced","optimized","pictorial","respectively","theoretical","classification","afterward","applications","reproducibility","compromise","modularity","unsupervised","supervised","scientific","usability","efficiency","distributed","reasonable"],"y":[65,58,897,30,352,15,589,40,38,12,11,123,162,9,50,57,225,13,164,205,1,117,38,134,14,236,247,26,103,0,6,109,9,81,130,15,577,223,19,118,14,829,119,51,3,72,239,307,27,16,18,10,2,2,8,3,236,20,5,127,96,7,180,363,10,44,35,23,5,143,74,142,2,51,57,8,244,100,81,11,100,190,1,3,20,154,318,1,8,4,59,12,46,318,31,37,116,169,159,67,156,10,429,727,57,19,19,133,8,9,11,3,86,44,49,40,71,1,0,118,3,6,87,119,391,30,76,333,153,246,28,710,54,14,2,81,44,86,83,54,17,104,1,35,336,4,101,529,14,109,260,65,7,216,115,155,112,3,124,9,213,9,79,60,30,76,213,110,342,18,2,27,147,15,287,48,16,614,32,14,49,21,136,46,2,99,153,487,2,419,7,6,8,132,180,46,9,174,101,53],"type":"bar"},{"x":["transform","discussed","performance","constructing","recognition","signature","expe ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4525,), (4525, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8175

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>ChatPainter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Improving</span> <span style=''>Text</span> <span style=''>to</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.6084656084656085);'>Generation</span> <span style=''>using</span> <span style=''>Dialogue</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Synthesizing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>realistic</span> <span style=''>images</span> <span style=''>from</span> <span style=''>text</span> <span style='background-color:rgba(0, 255, 0, 0.7714285714285714);'>descriptions</span> <span style=''>on</span> <span style=''>a</span> <span style=''>dataset</span> <span style=''>like</span> <span style='background-color:rgba(0, 255, 0, 0.49999999999999983);'>Microsoft</span> <span style=''>Common</span> <span style=''>Objects</span> <span style=''>in</span> <span style=''>Context</span> <span style=''>(MS</span> <span style=''>COCO)</span> <span style=''>where</span> <span style=''>each</span> <span style=''>image</span> <span style=''>can</span> <span style=''>contain</span> <span style=''>several</span> <span style=''>objects</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.41371158392434976);'>challenging</span> <span style=''>task</span> <span style=''>Prior</span> <span style=''>work</span> <span style=''>has</span> <span style=''>used</span> <span style=''>text</span> <span style=''>captions</span> <span style=''>to</span> <span style=''>generate</span> <span style=''>images</span> <span style=''>However</span> <span style=''>captions</span> <span style=''>might</span> <span style=''>not</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>informative</span> <span style=''>enough</span> <span style=''>to</span> <span style=''>capture</span> <span style=''>the</span> <span style=''>entire</span> <span style=''>image</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>insufficient</span> <span style=''>for</span> <span style=''>the</span> <span style=''>model</span> <span style=''>to</span> <span style=''>be</span> <span style=''>able</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understand</span> <span style=''>which</span> <span style=''>objects</span> <span style=''>in</span> <span style=''>the</span> <span style=''>images</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correspond</span> <span style=''>to</span> <span style=''>which</span> <span style=''>words</span> <span style=''>in</span> <span style=''>the</span> <span style=''>captions</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>adding</span> <span style=''>a</span> <span style=''>dialogue</span> <span style=''>that</span> <span style=''>further</span> <span style='background-color:rgba(0, 255, 0, 0.49606299212598426);'>describes</span> <span style=''>the</span> <span style=''>scene</span> <span style=''>leads</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3190348525469168);'>significant</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>improvement</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inception</span> <span style=''>score</span> <span style=''>and</span> <span style=''>in</span> <span style=''>the</span> <span style=''>quality</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>images</span> <span style=''>on</span> <span style=''>the</span> <span style=''>MS</span> <span style=''>COCO</span> <span style=''>dataset</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style=''>Boolean</span> <span style=''>Matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Factorisation</span> <br/><br/><span style=''>Boolean</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorisation</span> <span style=''>aims</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decompose</span> <span style=''>a</span> <span style=''>binary</span> <span style=''>data</span> <span style=''>matrix</span> <span style=''>into</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>Boolean</span> <span style=''>product</span> <span style=''>of</span> <span style=''>two</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>binary</span> <span style=''>matrices</span> <span style=''>one</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>containing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>meaningful</span> <span style=''>patterns</span> <span style=''>the</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantifying</span> <span style=''>how</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expressed</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combination</span> <span style=''>of</span> <span style=''>these</span> <span style=''>patterns</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>OrMachine</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>model</span> <span style=''>for</span> <span style=''>Boolean</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorisation</span> <span style=''>and</span> <span style=''>derive</span> <span style=''>a</span> <span style=''>Metropolised</span> <span style=''>Gibbs</span> <span style=''>sampler</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>facilitates</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>parallel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>On</span> <span style=''>real</span> <span style=''>world</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulated</span> <span style=''>data</span> <span style=''>our</span> <span style=''>method</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperforms</span> <span style=''>all</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>currently</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>for</span> <span style=''>Boolean</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorisation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>completion</span> <span style=''>This</span> <span style=''>is</span> <span style=''>the</span> <span style=''>first</span> <span style=''>method</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>full</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>for</span> <span style=''>Boolean</span> <span style=''>Matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorisation</span> <span style=''>wh ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>curves</span> <span style=''>for</span> <span style=''>multi</span> <span style=''>task</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style='background-color:rgba(255, 0, 0, 0.5052410901467506);'>regression</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>average</span> <span style=''>case</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>multi</span> <span style=''>task</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>(GP)</span> <span style='background-color:rgba(255, 0, 0, 0.5052410901467506);'>regression</span> <span style=''>as</span> <span style=''>captured</span> <span style=''>in</span> <span style=''>the</span> <span style=''>learning</span> <span style=''>curve</span> <span style=''>ie</span> <span style=''>the</span> <span style=''>average</span> <span style=''>Bayes</span> <span style=''>error</span> <span style=''>for</span> <span style=''>a</span> <span style=''>chosen</span> <span style=''>task</span> <span style=''>versus</span> <span style=''>the</span> <span style=''>total</span> <span style=''>number</span> <span style=''>of</span> <span style=''>examples</span> <span style=''>n</span> <span style=''>for</span> <span style=''>all</span> <span style=''>tasks</span> <span style=''>For</span> <span style=''>GP</span> <span style='background-color:rgba(255, 0, 0, 0.4117647058823529);'>covariances</span> <span style=''>that</span> <span style=''>are</span> <span style=''>the</span> <span style=''>product</span> <span style=''>of</span> <span style=''>an</span> <span style=''>input</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style='background-color:rgba(255, 0, 0, 0.5572519083969465);'>covariance</span> <span style=''>function</span> <span style=''>and</span> <span style=''>a</span> <span style=''>free</span> <span style=''>form</span> <span style=''>inter</span> <span style=''>task</span> <span style='background-color:rgba(255, 0, 0, 0.5572519083969465);'>covariance</span> <span style=''>matrix</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>accurate</span> <span style='background-color:rgba(255, 0, 0, 0.4857142857142856);'>approximations</span> <span style=''>for</span> <span style=''>the</span> <span style=''>learning</span> <span style=''>curve</span> <span style=''>can</span> <span style=''>be</span> <span style=''>obtained</span> <span style=''>for</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style=''>number</span> <span style=''>of</span> <span style=''>tasks</span> <span style=''>T</span> <span style=''>We</span> <span style=''>use</span> <span style=''>these</span> <span style=''>to</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6610169491525424);'>asymptotic</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>behaviour</span> <span style=''>for</span> <span style=''>large</span> <span style=''>n</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Surprisingly</span> <span style=''>multi</span> <span style=''>task</span> <span style=''>learning</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.5492957746478873);'>asymptotically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>essentially</span> <span style=''>useless</span> <span style=''>in</span> <span style=''>the</span> <span style=''>sense</span> <span style=''>that</span> <span style=''>examples</span> <span style=''>from</span> <span style=''>other</span> <span style=''>tasks</span> <span style=''>help</span> <span style=''>only</span> <span style=''>when</span> <span style=''>the</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Lossy</span> <span style=''>Image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Compression</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Compressive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Autoencoders</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoencoders</span> <span style=''>for</span> <span style=''>lossy</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compression</span> <span style=''>New</span> <span style=''>media</span> <span style=''>formats</span> <span style=''>changing</span> <span style=''>hardware</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technology</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>diverse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>requirements</span> <span style=''>and</span> <span style=''>content</span> <span style=''>types</span> <span style=''>create</span> <span style=''>a</span> <span style=''>need</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compression</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>which</span> <span style=''>are</span> <span style=''>more</span> <span style=''>flexible</span> <span style=''>than</span> <span style=''>existing</span> <span style=''>codecs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Autoencoders</span> <span style=''>have</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>to</span> <span style=''>address</span> <span style=''>this</span> <span style=''>need</span> <span style=''>but</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>optimize</span> <span style=''>directly</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>inherent</span> <span style=''>non</span> <span style=''>differentiabilty</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compression</span> <span style=''>loss</span> <span style=''>We</span> <span style=''>here</span> <span style=''>show</span> <span style=''>that</span> <span style=''>minimal</span> <span style=''>changes</span> <span style=''>to</span> <span style=''>the</span> <span style=''>loss</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficient</span> <span style=''>to</span> <span style=''>train</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoencoders</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>competitive</span> <span style=''>with</span> <span style=''>JPEG</span> <span style=''>2000</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperforming</span> <span style=''>recently</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>based</span> <span style=''>on</span> <span style=''>RNNs</span> <span style=''>Our</span> <span style=''>network</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>furthermore</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>thanks</span> <span style=''>to</span> <span style=''>a</span> <span style=''>sub</span> <span style=''>pixel< ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08007181328545782)
# 	knowledge (0.12280071813285458)
# 	challenging (0.1073608617594255)
# 	segmentation (0.06786355475763016)
# 	experimental (0.13464991023339318)
# 	detection (0.1324955116696589)
# 	information (0.25493716337522443)
# 	different (0.2610412926391382)
# 	recognition (0.12639138240574507)
# 	convolutional (0.14039497307001794)
#
# Some Statistics words are:
# 	variables (0.1325062034739454)
# 	stochastic (0.13895781637717122)
# 	algorithm (0.38461538461538464)
# 	theoretical (0.14789081885856079)
# 	estimation (0.171712158808933)
# 	distribution (0.17965260545905706)
# 	statistical (0.1598014888337469)
# 	inference (0.19106699751861042)
# 	dimensional (0.19106699751861042)
# 	regression (0.1781637717121588)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8aff3c1e-8e00-4954-a0ab-1ee21a88df5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8aff3c1e-8e00-4954-a0ab-1ee21a88df5e")) {                    Plotly.newPlot(                        "8aff3c1e-8e00-4954-a0ab-1ee21a88df5e",                        [{"x":["transform","discussed","performance","constructing","recognition","signature","experiments","verification","descriptor","determines","reproducing","convergence","generated","bootstrap","constructed","evaluating","distribution","quantifying","statistical","estimation","criticism","procedure","gradients","empirical","nonparametric","functions","complexity","divergence","approximate","quantiles","statistic","parameter","uncertainties","particularly","improvement","methodologies","demonstrate","architecture","maximizing","regression","intervals","algorithm","competitive","discovery","adjustments","conducted","parameters","optimization","confidence","modifications","initially","adjustment","appendices","commitment","practicality","prioritization","technique","otherwise","propagates","conditions","strategies","nontrivial","difficult","techniques","constants","operators","definitions","refinement","refinements","selection","magnitude","independent","unmodified","heuristic","polynomial","accelerating","effective","improvements","instances","crucially","improving","dimensional","countless","telescope","subspaces","potential","structure","penalizing","synthesizing","macroscopic","realistic","visualize","facilitate","computational","stability","generator","represent","challenge","probability","identifying","efficiently","concentrated","efficient","different","differences","diffusion","characterizing","corresponding","influences","appearances","densities","enumerating","represented","exploration","dimensions","measuring","statistics","metastable","attraction","translation","heuristically","summarizing","achieving","architectures","convolutional","treatment","predicting","representation","specifically","significant","systematic","information","measurements","laplacian","breathing","providing","modelling","computationally","demonstrated","requiring","qualitatively","approximation","bandlimited","acquisition","introduce","undersampled","performed","framework","reconstructions","reconstruction","application","mathematical","philosophy","properties","automated","furthermore","considered","researched","reasoning","argumentation","prediction","distillation","community","predictive","parametric","empirically","inference","processes","knowledge","alternatives","distilled","stationary","evaluated","optimally","available","designing","asymptotically","algorithms","allocation","maximizes","minimizing","interpolation","introduced","optimized","pictorial","respectively","theoretical","classification","afterward","applications","reproducibility","compromise","modularity","unsupervised","supervised","scientific","usability","efficiency","distributed","reasonable","libraries","consistently","assumption","variables","structural","confounding","individual","effectiveness","confounders","estimating","artificial","direction","distorted","relationship","nonlinear","observations","asymptotic","ambiguity","therefore","guarantee","classifier","multiclass","contained","classifiers","informative","appropriate","solutions","sometimes","practical","ambiguous","conditional","plausible","correctly","estimators","eigenproblem","eigenvectors","relaxation","encompasses","inclusion","retrieving","covariates","annotations","comparing","themselves","probabilistic","similarity","retrieved","experiment","employing","retrieval","likelihood","collection","maintaining","simulated","considerable","analytical","incorporat ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	quantiles
# 	attraction
# 	transposable
# 	distributionally
# 	impossibility
# 	unequally
# 	magnetoencephalographic
# 	abstention
# 	underestimation
# 	amortized
# 	reinterpret
# 	commonalities
# 	datapoints
# 	robustification
# 	marginalisation
# 	regularisation
# 	percentile
# 	robustify
# 	judiciously
# 	sparsification
# Some words which never appear in Statistics papers:
# 	appendices
# 	practicality
# 	researched
# 	argumentation
# 	pictorial
# 	mammalian
# 	foregrounds
# 	deepfashion
# 	thereafter
# 	synchronized
# 	groundtruth
# 	keyframes
# 	curiosity
# 	clickbait
# 	clickbaits
# 	unannotated
# 	publishers
# 	headlines
# 	shadowing
# 	ultrasound

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.088803088803089e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.78
